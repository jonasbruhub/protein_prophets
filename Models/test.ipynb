# %%
training_data = [(
    "the wall street journal reported today that apple corporation made money".split(),
    "B I I I O O O B I O O".split()
), (
    "georgia tech is a university in georgia".split(),
    "B I O O O O B".split()
)]

# %%
sentence, tags = training_data[0]

# %%
sentence
# Out:
# ['the',
#  'wall',
#  'street',
#  'journal',
#  'reported',
#  'today',
#  'that',
#  'apple',
#  'corporation',
#  'made',
#  'money']

# %%
"B I I I O O O B I O O".split()
# Out:
# ['B', 'I', 'I', 'I', 'O', 'O', 'O', 'B', 'I', 'O', 'O']

# %%
list("")
# Out:
# ['S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'S',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'O',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'P',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
#  'B',
# ...

# %%
tag_to_ix_inv = {0: "I", 1:"O", 2:"P", 3:"S", 4:"M", 5:"B", 6:4, 7:4}

# %%
l = ["dd","d","f"]

# %%
torch.tensor(l, dtype=torch.long)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-f31e0a6dfd0a> in <module>
# ----> 1 torch.tensor(l, dtype=torch.long)
#
# ValueError: too many dimensions 'str'
